# %%
import os
import pandas as pd

# %%
directory = 'C:/Users/FANNY MARIA D SOUZA/Capstone/DemographicInfo/'

# %%
df=pd.read_csv('blockdesignscore.csv')

# %% [markdown]
# #### Demographic Info - Complex Pie

# %%
demo_complexpie=pd.read_csv('Features_ComplexPie.csv')

# %%
demo_complexpie
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C001  Female                      36            171
# 1         C003  Female                      58            172
# 2         C006    Male                      42            199
# 3         C008  Female                      34            254
# 4         C009  Female                      24            198
# 5         C012  Female                      54            247
# 6         C013  Female                      48            266
# 7         C016    Male                      39            208
# 8         C017    Male                      36            170
# 9         C020  Female                      30            222
# 10        C021  Female                      29            191
# 11        C024  Female                      42            194
# 12        C025  Female                      24            159
# 13        C028    Male                      50            204
# 14        C029    Male                      34            142
# 15        C032  Female                      63            305
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         319.556571                         10                        161
# 1         362.351788                         10                        162
# 2         570.236635                         24                        175
# 3         466.281171                         27                        227
# 4         438.425413                          2                        196
# 5         532.936495                          8                        239
# 6         580.830070                         22                        244
# 7         517.807503                         13                        195
# 8         369.351203                         11                        159
# 9         565.967667                          7                        215
# 10        433.172928                         14                        177
# 11        288.786743                         18                        176
# 12        359.124353                         17                        142
# 13        858.494425                         18                        186
# 14        348.855143                          6                        136
# 15        556.955603                         20                        285
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  \
# 0        21.491310         20.968374                     18
# 1        35.154070         29.176267                     18
# 2        56.950739         23.036730                     18
# 3        58.660959         47.043500                     26
# 4        47.728880         32.351198                     26
# 5        53.877959         37.176239                     26
# 6        61.982680         45.411052                     26
# 7        46.610894         30.500671                     26
# 8        35.590809         20.441936                     19
# 9        34.357832         23.506672                     18
# 10       53.824557         17.917995                     21
# 11       28.894366         29.007836                     26
# 12       33.020450         16.108157                     18
# 13       90.978381         35.432651                     26
# 14       42.245812         19.796235                     14
# 15       29.614194         23.652023                     18
#
#     Apple Interactions - Add Apples  Add Sugar   Add apples to pan  \
# 0                                49          12                 75
# 1                                56           5                103
# 2                                25          15                 83
# 3                                87          15                164
# 4                                73          11                114
# 5                                83          10                131
# 6                                88           8                160
# 7                                68           7                109
# 8                                37          11                 49
# 9                                33          13                 52
# 10                                8          66                 20
# 11                               71           9                104
# 12                               31           5                 40
# 13                               91          18                123
# 14                               31          35                 59
# 15                               36          15                 73
#
#     Add cinnamon  Stir bowl  Put pie in oven
# 0             26         11               10
# 1              4          9               10
# 2             12         27               11
# 3              6         18               10
# 4              4         17                5
# 5             14         38                8
# 6              9         18                7
# 7             11         11                6
# 8              2         62                8
# 9             78         21               11
# 10            26          4               21
# 11             8         10               15
# 12            41          3               35
# 13             4          6               24
# 14             6          0                0
# 15            70         24               13

# %%
df = df[['Q1','Q2.1']].rename(columns={'Q1': 'Participant', 'Q2.1': 'Age'})
df_complexpie = pd.merge( demo_complexpie, df , on='Participant', how='inner')
df_complexpie
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C001  Female                      36            171
# 1         C003  Female                      58            172
# 2         C006    Male                      42            199
# 3         C008  Female                      34            254
# 4         C009  Female                      24            198
# 5         C012  Female                      54            247
# 6         C013  Female                      48            266
# 7         C016    Male                      39            208
# 8         C017    Male                      36            170
# 9         C020  Female                      30            222
# 10        C021  Female                      29            191
# 11        C024  Female                      42            194
# 12        C025  Female                      24            159
# 13        C028    Male                      50            204
# 14        C029    Male                      34            142
# 15        C032  Female                      63            305
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         319.556571                         10                        161
# 1         362.351788                         10                        162
# 2         570.236635                         24                        175
# 3         466.281171                         27                        227
# 4         438.425413                          2                        196
# 5         532.936495                          8                        239
# 6         580.830070                         22                        244
# 7         517.807503                         13                        195
# 8         369.351203                         11                        159
# 9         565.967667                          7                        215
# 10        433.172928                         14                        177
# 11        288.786743                         18                        176
# 12        359.124353                         17                        142
# 13        858.494425                         18                        186
# 14        348.855143                          6                        136
# 15        556.955603                         20                        285
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  \
# 0        21.491310         20.968374                     18
# 1        35.154070         29.176267                     18
# 2        56.950739         23.036730                     18
# 3        58.660959         47.043500                     26
# 4        47.728880         32.351198                     26
# 5        53.877959         37.176239                     26
# 6        61.982680         45.411052                     26
# 7        46.610894         30.500671                     26
# 8        35.590809         20.441936                     19
# 9        34.357832         23.506672                     18
# 10       53.824557         17.917995                     21
# 11       28.894366         29.007836                     26
# 12       33.020450         16.108157                     18
# 13       90.978381         35.432651                     26
# 14       42.245812         19.796235                     14
# 15       29.614194         23.652023                     18
#
#     Apple Interactions - Add Apples  Add Sugar   Add apples to pan  \
# 0                                49          12                 75
# 1                                56           5                103
# 2                                25          15                 83
# 3                                87          15                164
# 4                                73          11                114
# 5                                83          10                131
# 6                                88           8                160
# 7                                68           7                109
# 8                                37          11                 49
# 9                                33          13                 52
# 10                                8          66                 20
# 11                               71           9                104
# 12                               31           5                 40
# 13                               91          18                123
# 14                               31          35                 59
# 15                               36          15                 73
#
#     Add cinnamon  Stir bowl  Put pie in oven Age
# 0             26         11               10  21
# 1              4          9               10  25
# 2             12         27               11  35
# 3              6         18               10  25
# 4              4         17                5  26
# 5             14         38                8  25
# 6              9         18                7  26
# 7             11         11                6  28
# 8              2         62                8  24
# 9             78         21               11  28
# 10            26          4               21  28
# 11             8         10               15  24
# 12            41          3               35  25
# 13             4          6               24  23
# 14             6          0                0  25
# 15            70         24               13  18

# %%
df_complexpie['Age'] = pd.to_numeric(df_complexpie['Age'], errors='coerce')
age_summary_cp=df_complexpie['Age'].describe()
age_summary_cp
# Out:
# count    16.000000
# mean     25.375000
# std       3.630886
# min      18.000000
# 25%      24.000000
# 50%      25.000000
# 75%      26.500000
# max      35.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_complexpie['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    11
# Male       5
# Name: count, dtype: int64

# %% [markdown]
# #### Demographic Info - Simple Pie

# %%
demo_simplepie=pd.read_csv('Features_SimplePie.csv')

# %%
demo_simplepie
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C002  Female                      28            231
# 1         C004    Male                      30            106
# 2         C005  Female                      46            224
# 3         C010  Female                      54            189
# 4         C014  Female                      32            252
# 5         C015  Female                      33            148
# 6         C018    Male                      50            225
# 7         C019  Female                      40            149
# 8         C023  Female                      52            179
# 9         C026  Female                      33            269
# 10        C027  Female                      41            194
# 11        C030  Female                      39            159
# 12        C031    Male                      61            149
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         441.284316                         30                        201
# 1         267.087071                         10                         96
# 2         420.203874                         24                        200
# 3         391.381875                         29                        160
# 4         373.759417                         12                        240
# 5         179.116540                          7                        141
# 6         460.775250                         37                        188
# 7         251.291784                         14                        135
# 8         332.910903                         17                        162
# 9         615.561959                         18                        251
# 10        329.012081                         17                        177
# 11        321.537060                         33                        126
# 12        241.995862                         28                        121
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  \
# 0        50.340261         24.617067                     18
# 1        29.587162         11.430422                     18
# 2        42.595820         26.613052                     18
# 3        32.157613         22.471396                     18
# 4        31.466625         37.179173                     26
# 5        16.728146         25.625626                     26
# 6        62.982422         28.409025                     26
# 7        23.819270         14.073831                     18
# 8        30.494925         20.847498                     26
# 9        61.220314         28.549479                     18
# 10       31.455011         33.374459                     26
# 11       37.353355         23.183458                     18
# 12       17.418283         20.353691                     26
#
#     Apple Interactions - Add Apples  Add Sugar   Add apples to pan  \
# 0                                42          70                 68
# 1                                28          28                 36
# 2                                52          19                 85
# 3                                66          22                 81
# 4                                70           9                127
# 5                                65           8                 90
# 6                                70          46                 98
# 7                                39           8                 48
# 8                                58          16                 76
# 9                                39          92                 57
# 10                               81          16                117
# 11                               42          35                 78
# 12                               62          12                 73
#
#     Add cinnamon  Stir bowl  Put pie in oven
# 0              7          7               12
# 1              2          6                7
# 2             52          4               33
# 3              5          6               15
# 4              8          3               10
# 5              2         14                7
# 6              3         12                7
# 7             29          7                7
# 8              5         14               25
# 9             47         16               13
# 10             4         18                7
# 11             2          4                9
# 12             6          5               11

# %%
df_simplepie = pd.merge( demo_simplepie, df , on='Participant', how='inner')
df_simplepie
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C002  Female                      28            231
# 1         C004    Male                      30            106
# 2         C005  Female                      46            224
# 3         C010  Female                      54            189
# 4         C014  Female                      32            252
# 5         C015  Female                      33            148
# 6         C018    Male                      50            225
# 7         C019  Female                      40            149
# 8         C023  Female                      52            179
# 9         C026  Female                      33            269
# 10        C027  Female                      41            194
# 11        C030  Female                      39            159
# 12        C031    Male                      61            149
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         441.284316                         30                        201
# 1         267.087071                         10                         96
# 2         420.203874                         24                        200
# 3         391.381875                         29                        160
# 4         373.759417                         12                        240
# 5         179.116540                          7                        141
# 6         460.775250                         37                        188
# 7         251.291784                         14                        135
# 8         332.910903                         17                        162
# 9         615.561959                         18                        251
# 10        329.012081                         17                        177
# 11        321.537060                         33                        126
# 12        241.995862                         28                        121
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  \
# 0        50.340261         24.617067                     18
# 1        29.587162         11.430422                     18
# 2        42.595820         26.613052                     18
# 3        32.157613         22.471396                     18
# 4        31.466625         37.179173                     26
# 5        16.728146         25.625626                     26
# 6        62.982422         28.409025                     26
# 7        23.819270         14.073831                     18
# 8        30.494925         20.847498                     26
# 9        61.220314         28.549479                     18
# 10       31.455011         33.374459                     26
# 11       37.353355         23.183458                     18
# 12       17.418283         20.353691                     26
#
#     Apple Interactions - Add Apples  Add Sugar   Add apples to pan  \
# 0                                42          70                 68
# 1                                28          28                 36
# 2                                52          19                 85
# 3                                66          22                 81
# 4                                70           9                127
# 5                                65           8                 90
# 6                                70          46                 98
# 7                                39           8                 48
# 8                                58          16                 76
# 9                                39          92                 57
# 10                               81          16                117
# 11                               42          35                 78
# 12                               62          12                 73
#
#     Add cinnamon  Stir bowl  Put pie in oven Age
# 0              7          7               12  26
# 1              2          6                7  26
# 2             52          4               33  24
# 3              5          6               15  26
# 4              8          3               10  25
# 5              2         14                7  25
# 6              3         12                7  26
# 7             29          7                7  22
# 8              5         14               25  23
# 9             47         16               13  24
# 10             4         18                7  26
# 11             2          4                9  25
# 12             6          5               11  25

# %%
df_simplepie['Age'] = pd.to_numeric(df_simplepie['Age'], errors='coerce')
age_summary_sp=df_simplepie['Age'].describe()
age_summary_sp
# Out:
# count    13.000000
# mean     24.846154
# std       1.281025
# min      22.000000
# 25%      24.000000
# 50%      25.000000
# 75%      26.000000
# max      26.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_simplepie['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    10
# Male       3
# Name: count, dtype: int64

# %% [markdown]
# #### Demographic Info - Complex Stew

# %%
demo_complexstew=pd.read_csv('Features_ComplexStew.csv')

# %%
demo_complexstew
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C002  Female                      28            236
# 1         C004    Male                      30            230
# 2         C005  Female                      46            244
# 3         C011  Female                      34            317
# 4         C014  Female                      32            149
# 5         C015  Female                      33            328
# 6         C018    Male                      50            175
# 7         C019  Female                      40            222
# 8         C023  Female                      52            296
# 9         C026  Female                      33            202
# 10        C027  Female                      41            167
# 11        C031    Male                      61            303
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         379.717201                          7                        229
# 1         448.278247                         11                        219
# 2         630.314119                         26                        218
# 3         441.342282                         68                        249
# 4         301.389534                         13                        136
# 5         477.137853                         18                        310
# 6         311.229064                          6                        169
# 7         392.315865                          3                        219
# 8         512.460218                          7                        289
# 9         392.338178                          1                        201
# 10        288.690354                          4                        163
# 11        631.112215                         46                        257
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  Add Onion  \
# 0        27.092263         19.574360                     28         31
# 1        33.319354         20.709633                     28         63
# 2        46.989878         25.988031                     24         27
# 3        40.778881         34.486874                     19         57
# 4        14.376381         13.527339                     24         20
# 5        34.377668         30.626060                     32         34
# 6        17.584074         15.629388                     32         24
# 7        29.693535         24.380320                     28         81
# 8        52.261754         36.080774                     32         38
# 9        20.106392         15.597721                     28         47
# 10       16.154880         15.874858                     32         22
# 11       59.936255         31.941092                     32         52
#
#     Add Tomtato  Add Beef
# 0            20        57
# 1            22        34
# 2            27        36
# 3            26        98
# 4            26         0
# 5            35        89
# 6            25        46
# 7            19        29
# 8            26       105
# 9            22        36
# 10           18        43
# 11           20       108

# %%
df_complexstew = pd.merge( demo_complexstew, df , on='Participant', how='inner')
df_complexstew
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C002  Female                      28            236
# 1         C004    Male                      30            230
# 2         C005  Female                      46            244
# 3         C011  Female                      34            317
# 4         C014  Female                      32            149
# 5         C015  Female                      33            328
# 6         C018    Male                      50            175
# 7         C019  Female                      40            222
# 8         C023  Female                      52            296
# 9         C026  Female                      33            202
# 10        C027  Female                      41            167
# 11        C031    Male                      61            303
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         379.717201                          7                        229
# 1         448.278247                         11                        219
# 2         630.314119                         26                        218
# 3         441.342282                         68                        249
# 4         301.389534                         13                        136
# 5         477.137853                         18                        310
# 6         311.229064                          6                        169
# 7         392.315865                          3                        219
# 8         512.460218                          7                        289
# 9         392.338178                          1                        201
# 10        288.690354                          4                        163
# 11        631.112215                         46                        257
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  Add Onion  \
# 0        27.092263         19.574360                     28         31
# 1        33.319354         20.709633                     28         63
# 2        46.989878         25.988031                     24         27
# 3        40.778881         34.486874                     19         57
# 4        14.376381         13.527339                     24         20
# 5        34.377668         30.626060                     32         34
# 6        17.584074         15.629388                     32         24
# 7        29.693535         24.380320                     28         81
# 8        52.261754         36.080774                     32         38
# 9        20.106392         15.597721                     28         47
# 10       16.154880         15.874858                     32         22
# 11       59.936255         31.941092                     32         52
#
#     Add Tomtato  Add Beef Age
# 0            20        57  26
# 1            22        34  26
# 2            27        36  24
# 3            26        98  25
# 4            26         0  25
# 5            35        89  25
# 6            25        46  26
# 7            19        29  22
# 8            26       105  23
# 9            22        36  24
# 10           18        43  26
# 11           20       108  25

# %%
df_complexstew['Age'] = pd.to_numeric(df_complexstew['Age'], errors='coerce')
age_summary_cs=df_complexstew['Age'].describe()
age_summary_cs
# Out:
# count    12.000000
# mean     24.750000
# std       1.288057
# min      22.000000
# 25%      24.000000
# 50%      25.000000
# 75%      26.000000
# max      26.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_complexstew['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    9
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# #### Demographic Info - Simple Stew

# %%
demo_simplestew=pd.read_csv('Features_SimpleStew.csv')

# %%
demo_simplestew
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C001  Female                      36            180
# 1         C003  Female                      58            212
# 2         C006    Male                      42            216
# 3         C008  Female                      34            290
# 4         C009  Female                      24            344
# 5         C012  Female                      54            163
# 6         C013  Female                      48            314
# 7         C016    Male                      39            183
# 8         C017    Male                      36            218
# 9         C020  Female                      30            212
# 10        C021  Female                      29            310
# 11        C024  Female                      42            156
# 12        C025  Female                      24            160
# 13        C028    Male                      50            180
# 14        C032  Female                      63            181
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         241.813972                          3                        177
# 1         368.939742                         13                        199
# 2         258.609221                         45                        171
# 3         316.882270                          9                        281
# 4         450.877417                         16                        328
# 5         240.627667                          1                        162
# 6         530.895012                         35                        279
# 7         185.527859                         16                        167
# 8         335.729737                         12                        206
# 9         320.340694                          1                        211
# 10        481.343316                         14                        296
# 11        188.807745                          4                        152
# 12        317.064713                         12                        148
# 13        283.077166                          3                        177
# 14        214.467324                          5                        176
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  Add Onion  \
# 0        19.373010         15.033296                     28         33
# 1        35.630609         18.443909                     28         35
# 2        19.902276         24.180800                     28         26
# 3        20.357014         27.190685                     32         55
# 4        47.383847         46.421259                     28          0
# 5        14.958293         15.122096                     32         28
# 6        35.520103         25.382409                     30         48
# 7        11.689684         18.523559                     32         24
# 8        25.446555         20.384090                     28         57
# 9        17.424497         18.023442                     28         54
# 10       35.932085         26.072548                     28         49
# 11       10.711102         14.017449                     32         19
# 12       21.660530         15.033296                     28         42
# 13       19.425701         17.441967                     32         34
# 14       16.958552         19.996944                     28         34
#
#     Add Tomtato  Add Beef
# 0            25        35
# 1            18        59
# 2            24        33
# 3            34        72
# 4            32       153
# 5            20        42
# 6            29        74
# 7            21        60
# 8            26        49
# 9            23        30
# 10           29        83
# 11           17        43
# 12           18        28
# 13           22        45
# 14           17        64

# %%
df_simplestew = pd.merge( demo_simplestew, df , on='Participant', how='inner')
df_simplestew
# Out:
#    Participant  Gender  Block Design Raw Score  Total Actions  \
# 0         C001  Female                      36            180
# 1         C003  Female                      58            212
# 2         C006    Male                      42            216
# 3         C008  Female                      34            290
# 4         C009  Female                      24            344
# 5         C012  Female                      54            163
# 6         C013  Female                      48            314
# 7         C016    Male                      39            183
# 8         C017    Male                      36            218
# 9         C020  Female                      30            212
# 10        C021  Female                      29            310
# 11        C024  Female                      42            156
# 12        C025  Female                      24            160
# 13        C028    Male                      50            180
# 14        C032  Female                      63            181
#
#     Total Time Spent  Total Missed Interactions  Total Object Interactions  \
# 0         241.813972                          3                        177
# 1         368.939742                         13                        199
# 2         258.609221                         45                        171
# 3         316.882270                          9                        281
# 4         450.877417                         16                        328
# 5         240.627667                          1                        162
# 6         530.895012                         35                        279
# 7         185.527859                         16                        167
# 8         335.729737                         12                        206
# 9         320.340694                          1                        211
# 10        481.343316                         14                        296
# 11        188.807745                          4                        152
# 12        317.064713                         12                        148
# 13        283.077166                          3                        177
# 14        214.467324                          5                        176
#
#     Time Spent S.D  Action Count S.D  Total Completed Steps  Add Onion  \
# 0        19.373010         15.033296                     28         33
# 1        35.630609         18.443909                     28         35
# 2        19.902276         24.180800                     28         26
# 3        20.357014         27.190685                     32         55
# 4        47.383847         46.421259                     28          0
# 5        14.958293         15.122096                     32         28
# 6        35.520103         25.382409                     30         48
# 7        11.689684         18.523559                     32         24
# 8        25.446555         20.384090                     28         57
# 9        17.424497         18.023442                     28         54
# 10       35.932085         26.072548                     28         49
# 11       10.711102         14.017449                     32         19
# 12       21.660530         15.033296                     28         42
# 13       19.425701         17.441967                     32         34
# 14       16.958552         19.996944                     28         34
#
#     Add Tomtato  Add Beef Age
# 0            25        35  21
# 1            18        59  25
# 2            24        33  35
# 3            34        72  25
# 4            32       153  26
# 5            20        42  25
# 6            29        74  26
# 7            21        60  28
# 8            26        49  24
# 9            23        30  28
# 10           29        83  28
# 11           17        43  24
# 12           18        28  25
# 13           22        45  23
# 14           17        64  18

# %%
df_simplestew['Age'] = pd.to_numeric(df_simplestew['Age'], errors='coerce')
age_summary_ss=df_simplestew['Age'].describe()
age_summary_ss
# Out:
# count    15.000000
# mean     25.400000
# std       3.756898
# min      18.000000
# 25%      24.000000
# 50%      25.000000
# 75%      27.000000
# max      35.000000
# Name: Age, dtype: float64

# %%
gender_counts=df_simplestew['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    11
# Male       4
# Name: count, dtype: int64

# %% [markdown]
# #### T-test between Simple Pie and Complex Pie

# %%
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(df_simplepie['Age'], df_complexpie['Age'], nan_policy='omit')
t_stat, p_value
# Out:
# (-0.49908196523771886, 0.6217638963001795)

# %% [markdown]
# #### T-test between Simple Stew and Complex Stew

# %%
from scipy.stats import ttest_ind

t_stat, p_value = ttest_ind(df_simplestew['Age'], df_complexstew['Age'], nan_policy='omit')
t_stat, p_value
# Out:
# (0.5711651554298773, 0.5729870207735634)
